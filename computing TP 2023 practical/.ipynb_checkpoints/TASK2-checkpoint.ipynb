# %%
#Task 2.1
import pymongo, json
client = pymongo.MongoClient("mongodb://localhost:27017/")
db = client["social_db"]
Users = db["Users"]
Users.delete_many({})
with open("USERS-1.json") as file:
    data = json.load(file)
    for row in data:
        headers = row.keys()
        Users.insert_one(row)
client.close()
print("successfully inserted all records into database")
# Out:
# successfully inserted all records into database

# %%
#Task 2.2
#compulsory = userID, name, email, gender, dateOfBirth,
def add_record(compulsory, yearOfRegistration = 2026, active = 1):
    if yearOfRegistration == '':
        YeadOfRegistration = 2026
    if active == '':
        active = 1
    Users.insert_one(dict(zip(headers,compulsory+(yearOfRegistration, active))))
        
print("DATABASE ACCESS\nplease key in your record fields to insert into database\nyear of registration and active status is optional")
status = ''
client = pymongo.MongoClient("mongodb://localhost:27017/")
db = client["social_db"]
Users = db["Users"]
while status != 'quit':
    add_record((input("key in user id: "), input("key in name: "), input("key in email: "), input("key in gender: "), input("key in date of birth: ")), input("key in year of registration (optional, leave blank to skip): "), input("key in active status (optional, leave blank to skip): "))
    status = input("successfully inserted record, leave blank to continue, type 'quit' to quit menu: ")
client.close()
# Out:
# DATABASE ACCESS
# please key in your record fields to insert into database
# year of registration and active status is optional
# key in user idU862943
# key in nameMei Ling
# key in emailmei.ling39@yahoo.com
# key in genderF
# key in date of birth06/01/2004
# key in year of registration (optional, leave blank to skip)2026
# key in active status (optional, leave blank to skip)1
# successfully inserted record, leave blank to continue, type 'quit' to quit menu
# key in user idU269178
# key in nameWei Chen
# key in emailwei.chen44@yahoo.com
# key in genderM
# key in date of birth31/03/1999
# key in year of registration (optional, leave blank to skip)
# key in active status (optional, leave blank to skip)
# successfully inserted record, leave blank to continue, type 'quit' to quit menuquit

# %%
#Task 2.3
option = 0
platforms = ['',"phasebookFriends","viewtubeSubscribers","whatsupContacts"]
while option != 4:
    print("""
    Display Users
    [1] Phasebook Users
    [2] Viewtube Users
    [3] Whatsup Users
    [4] Quit
    """)
    option = input("key in the integer for your option: ")
    counter = 0
    print(f"UserID Name Number of {platform[option]})
    for result in Users.find({platforms[option]}):
        print(f"""
        {result["UserID"], result["Name"], result[platform[option]]}
        """)
        counter += 1
    print(f"number of documents = {counter})\n")
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
