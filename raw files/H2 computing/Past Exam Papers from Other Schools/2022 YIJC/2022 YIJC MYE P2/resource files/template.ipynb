# %% [markdown]
# ## 2022 J2 H2 Computing Mid Year Exam Template
#
# 1. Rename this template.ipynb to MYE_<your_class>_<your_name>.ipynb
# 2. Run the following code to enter your name and class.

# %%
Name = input('Enter your Full name : ')
CG = input('Enter your class : ')

# %% [markdown]
# ---
# ## Question 1

# %%
#Task 1 menu code provided. Do not modify.

found_list = ['bottle', 'iphone', 'calculator', 'wallet', 'watch']

def menu():
    inputstring = "Default"
    while inputstring != "":
        print("\nMenu:")
        print("1. Check for Lost and Found items")
        print("2. Delete an item returned to student")
        print("3. Add a new Lost and Found item")
        inputstring = input("Select an option or press Enter to quit: ")
        if inputstring == "1":
            check()
        elif inputstring == "2":
            delete()
        elif inputstring == "3":
            add()

# %% [markdown]
# ### Task 1.1

# %%
#Task 1.1

def check():
    pass

# %%
#Testing Task 1.1
menu()

# %% [markdown]
# ### Task 1.2

# %%
#Task 1.2

def delete():
    pass

# %%
#Testing Task 1.2
menu()

# %% [markdown]
# ### Task 1.3

# %%
#Task 1.3

def add():
    pass

# %%
#Testing Task 1.3
menu()

# %% [markdown]
# ---
# ## Question 2
#
# ### Task 2.1

# %%
#Task 2.1

def hashkey(name):
    pass

# %%
#Test Case for Task 2.1
hashkey('Brazil')

# %% [markdown]
# ### Task 2.2

# %%
# Task 2.2

# %% [markdown]
# ### Task 2.3

# %%
# Task 2.3

# %% [markdown]
# ### Task 2.4

# %%
# Task 2.4
def search(table, name):
    pass

# %%
#Test Case for Task 2.4
print(search(HashTable, 'USA'))
print(search(HashTable, 'Brazil'))
print(search(HashTable, 'Vietnam'))

# %% [markdown]
# ---
# ## Question 3
#
# ### Task 3.1

# %%
#Task 3.1

###########################################
#######Do not edit below this line#########
###########################################
class Package:
    def __init__(self, data, next = None):
        self.data = data
        self.next = next                                        
    
    def get_data(self):
        return self.data
    
    def get_next(self):                                        
        return self.next

    def set_data(self, new_data):
        self.data = new_data

    def set_next(self, new_next):                               
        self.next = new_next

class Queue:
    def __init__(self, root = None):
        self.root = root

    def IsEmpty(self):
        return self.root == None                                 

    def enqueue(self, data):
        new_pack = Package(data, self.root)                       
        self.root = new_pack                                      
###########################################
#######Do not edit above this line#########
###########################################

#complete the 2 methods below
    def dequeue():
        pass
    
    def display():
        pass

# %%
#Test Case for Task 3.1

# %% [markdown]
# ### Task 3.2

# %%
#Task 3.2

# %%
#Test Case and Data for Task 3.2

jobs = ['AMZ001', 'LAZ001', 'AMZ002', 'SHP001', 'SHP002']

# %% [markdown]
# ### Task 3.3

# %%
#Task 3.3

###########################################
#######Do not edit below this line#########
###########################################
class Package:
    def __init__(self, data, next = None):
        self.data = data
        self.next = next                                        
    
    def get_data(self):
        return self.data
    
    def get_next(self):                                        
        return self.next

    def set_data(self, new_data):
        self.data = new_data

    def set_next(self, new_next):                               
        self.next = new_next

class Queue:
    def __init__(self, root = None):
        self.root = root

    def IsEmpty(self):
        return self.root == None                                 

    def enqueue(self, data):
        package = Package(data, self.root)                       
        self.root = package                                      
###########################################
#######Do not edit above this line#########
###########################################

#copy and paste the 2 methods from Task 3.1
    def dequeue():
        pass
    
    def display():
        pass

#complete the method below
    def cancel():
        pass

# %%
#Test Case for Task 3.3
deliver26may.cancel('LAZ001')
deliver26may.display()

# %% [markdown]
# ---
# ## Question 5
#
# ### Task 5.1

# %%
# Task 5.1

from pymongo import *
from csv import *

# %% [markdown]
# ### Task 5.2

# %%
# Task 5.2

from pymongo import *
from csv import *

# %% [markdown]
# ### Task 5.3

# %%
# Task 5.3

from pymongo import *
from csv import *

# %% [markdown]
# ---
# ### ~ End of Paper ~
